# %%
from Util import util
all_path = util.create_or_find_date_dir()

# %%
import os
for filename in os.listdir(all_path):
    # print(filen
    # ame)
    major_path = os.path.join(all_path, filename)
    pdf_path = os.path.join(major_path,filename) + ".pdf"
    txt_path = os.path.join(major_path, filename) + ".txt"
    json_path = os.path.join(major_path, filename) + ".json"
    # print(file_pdf)
    if not os.path.exists(pdf_path):
        print("pdf不存在")
        continue
    if not os.path.exists(txt_path):
        text = util.get_str_from_pdf(pdf_path)
        with open(txt_path, 'w', encoding='utf-8') as f:
            f.write(text)
        print(f"txt已生成于目录{txt_path}")
    if os.path.exists(json_path):
        print("json文件已存在")
        continue
    with open(json_path, 'w', encoding='utf-8') as f:
        f.write("")
# Out:
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在
# json文件已存在

# %%
import json
import os
all_tag_path = './Corpus_Path/all_tag.json'
key_mapping_path = './Corpus_Path/key_mapping.json'
with open(all_tag_path, 'r', encoding='utf-8')as f:
    all_tag = json.load(f)
with open(key_mapping_path, 'r', encoding='utf-8')as f:
    key_mapping = json.load(f)
all_tag,key_mapping
# Out:
# ({'name': '',
#   'bir': '',
#   'age': '',
#   'email': '',
#   'gend': '',
#   'tel': '',
#   'acad': '',
#   'nati': '',
#   'live': '',
#   'poli': '',
#   'unv': '',
#   'work_experience': [{'time': '', 'org': '', 'role': '', 'work_desc': ''}],
#   'education': [{'time': '', 'school': '', 'degree': '', 'edu_desc': ''}],
#   'project_experience': [{'time': '',
#     'project': '',
#     'role': '',
#     'project_desc': ''}],
#   'training_experience': [{'time': '', 'training': '', 'training_desc': ''}],
#   'awards': [{'time': '', 'award': ''}],
#   'self_assessment': '',
#   'career_objective': '',
#   'skills': '',
#   'interests': '',
#   'certifications': '',
#   'language_skills': '',
#   'publications': '',
#   'philosophy': '',
#   'major_courses': '',
#   'self_introduction': '',
#   'other': ''},
#  {'name': 'NM',
#   'bir': 'BR',
#   'age': 'AG',
#   'email': 'EM',
#   'gend': 'GD',
#   'tel': 'TL',
#   'acad': 'AC',
#   'nati': 'NT',
#   'live': 'LV',
#   'poli': 'PL',
#   'unv': 'UV',
#   'time': 'TM',
#   'org': 'OG',
#   'role': 'RL',
#   'work_desc': 'WD',
#   'school': 'SC',
#   'degree': 'DG',
#   'edu_desc': 'ES',
#   'project': 'PJ',
#   'project_desc': 'PD',
#   'training': 'TR',
#   'training_desc': 'TD',
#   'work_experience': 'WE',
#   'education': 'ED',
#   'project_experience': 'PE',
#   'training_experience': 'TE',
#   'awards': 'AW',
#   'self_assessment': 'SA',
#   'career_objective': 'CO',
#   'skills': 'SK',
#   'interests': 'IN',
#   'certifications': 'CE',
#   'language_skills': 'LS',
#   'publications': 'PU',
#   'philosophy': 'PH',
#   'major_courses': 'MC',
#   'self_introduction': 'SI',
#   'other': 'OT'})

# %%
from Util import util
from pprint import pprint
import os
all_path = util.create_or_find_date_dir()
index = 0
for filename in os.listdir(all_path):
    # print(filename)
    major_path = os.path.join(all_path, filename)
    pdf_path = os.path.join(major_path,filename) + ".pdf"
    txt_path = os.path.join(major_path, filename) + ".txt"
    json_path = os.path.join(major_path, filename) + ".json"
    # print(file_pdf)
    if not os.path.exists(pdf_path):
        print("pdf不存在")
        continue
    if not os.path.exists(txt_path):
        text = util.get_str_from_pdf(pdf_path)
        with open(txt_path, 'w', encoding='utf-8') as f:
            f.write(text)
        print(f"未解析pdf,txt已生成于目录{txt_path}")
    else:
        with open(txt_path, 'r', encoding='utf-8') as f:
            text = f.read()
    if os.path.exists(json_path):
        print(f"json文件已存在{json_path}")
        with open(json_path, 'r', encoding='utf-8') as f:
            ner_json = json.load(f)
        # 等会改
        # continue
    # with open(json_path, 'w', encoding='utf-8') as f:
    #     f.write("")
    print(key_mapping)
    # 从标注好的json文件中映射原始文本索引
    json_index = util.get_index_by_automaton(ner_json,key_mapping,text)
    pprint(json_index)
    # 标注好的json文件
    for key, value in ner_json.items():
        print(value)
    index = index + 1
    if index >= 1:
        break
# Out:
# json文件已存在./Corpus_Path\2024年03月03日15时01分\101\101.json
# {'name': 'NM', 'bir': 'BR', 'age': 'AG', 'email': 'EM', 'gend': 'GD', 'tel': 'TL', 'acad': 'AC', 'nati': 'NT', 'live': 'LV', 'poli': 'PL', 'unv': 'UV', 'time': 'TM', 'org': 'OG', 'role': 'RL', 'work_desc': 'WD', 'school': 'SC', 'degree': 'DG', 'edu_desc': 'ES', 'project': 'PJ', 'project_desc': 'PD', 'training': 'TR', 'training_desc': 'TD', 'work_experience': 'WE', 'education': 'ED', 'project_experience': 'PE', 'training_experience': 'TE', 'awards': 'AW', 'self_assessment': 'SA', 'career_objective': 'CO', 'skills': 'SK', 'interests': 'IN', 'certifications': 'CE', 'language_skills': 'LS', 'publications': 'PU', 'philosophy': 'PH', 'major_courses': 'MC', 'self_introduction': 'SI', 'other': 'OT'}
# []
# 蔡于纬
# 23
# 13511223344
# 广东省广州市
# [{'time': '2022.08至今', 'org': '卓望信息科技有限公司', 'role': '营运推广主管', 'work_desc': '负责社会化媒体营销团队的搭建工作，制定相关运营策略和指标，带领团队实施计划；网站常态运营活动规划和推进执行；相关数据报告和统计，为公司决策层提供决策依据；轻量级产品和应用的策划，统筹产品、技术团队成员实施。'}, {'time': '2021.8-2022.8', 'org': '广州灵心沙文化活动有限公司', 'role': '市场推广专员', 'work_desc': '网络推广渠道搭建维护，包括QQ空间、微博、豆瓣等；负责软硬广投放，网络舆情监控，公关稿撰写，事件营销策划；标书制作和撰写，甲方沟通工作。'}]
# [{'time': '2018.9-2021.6', 'school': '华南师范大学附属中学', 'degree': '高中', 'edu_desc': '主修课程：基本会计、统计学、市场营销、国际市场营销、市场调查与预测、商业心理学、广告学、公共关系学、货币银行学、经济法、国际贸易、大学英语、计算机应用等。'}]
# 本人有丰富的营销知识体系做基础；对于市场营销方面的前沿和动向有一定的了解，善于分析和吸取经验；熟悉网络推广，尤其是社会化媒体方面，有独到的见解和经验；个性开朗，容易相处，团队荣誉感强。
# 市场专员
# CET-6，优秀的听说写能力；计算机二级，熟悉计算机各项操作；高级营销员，国家职业资格四级。
# service@500d.me

# %%
def marking_tag_idex(json_text,txt_text,key_mapping=key_mapping,log_info="101"):
    """
    打标记--二级处理的时候不在后面加上0和1的标识符
    :param json_text: 原始标注好的json文件
    :param txt_text: 原始文本
    :param key_mapping: 简写映射
    :param log_info: 日志文本
    :return:
    """
    import re
    from Util.util import get_index_by_automaton,get_log_config
    from pprint import pprint
    log_config = get_log_config()
    def get_text_index(search_string,tag):
        """
        用于标注字段
        :param search_string:被查找的字符串,充当返回的key值，便于查找
        :param tag: 标注的标志
        :param name: logging信息，文件名称便于定位错误信息
        :return:list
        """
        # 变量初始化
        automaton_info = []
        # 若找得到文本
        if txt_text.find(search_string) != -1:
            start_idx = txt_text.find(search_string)
            end_idx = start_idx + len(search_string) - 1
            automaton_info = [{
                search_string: {
                    "start_index": start_idx,
                    "end_index": end_idx,
                    "tag": tag,
                }
            }]
            log_config.info(f"{log_info}文件 {search_string} 标注为 {tag}")
            # print(automaton_info)
        # 找不到文本
        else:
            pattern = r'[、，。；：？！,.;:?!]'
            # 使用正则表达式分割文本
            segments = re.split(pattern, search_string)
            segments.pop()
            # print(segments)
            log_config.warning(f"{log_info}文件 {search_string} 标注为 :")
            log_config.error(f"{log_info}文件 {search_string} 未标注为 :")
            automaton_info = get_index_by_automaton(segments,tag,txt_text)
            # pprint(automaton_info)
        return automaton_info
    all_tag_list = []
    # 遍历一级结构字典
    # pprint(json_text)
    for key, value in json_text.items():
        if isinstance(value, str):  # 如果字段值是字符串，则直接添加
            new_key = key_mapping[key]
            for split_tag in get_text_index(value,new_key):
                all_tag_list.append(split_tag)
        elif isinstance(value, list):
            # 遍历二级结构列表
            for item in value:
                # 遍历字典
                for sub_key, sub_value in item.items():
                    new_key = key_mapping[key]+"_"+key_mapping[sub_key]
                    split_tag_list = get_text_index(sub_value,new_key)
                    pprint(split_tag_list)
                    # print(index,item)
                    for split_tag in split_tag_list:
                        all_tag_list.append(split_tag)
    return all_tag_list
all_tag_index = marking_tag_idex(ner_json,text)
from pprint import pprint
pprint(all_tag_index)
# Out:
# [{'2022.08至今': {'end_index': 180, 'start_index': 172, 'tag': 'WE_TM'}}]
# [{'卓望信息科技有限公司': {'end_index': 190, 'start_index': 181, 'tag': 'WE_OG'}}]
# [{'营运推广主管': {'end_index': 196, 'start_index': 191, 'tag': 'WE_RL'}}]
# [{'负责社会化媒体营销团队的搭建工作': {'end_index': 214, 'start_index': 199, 'tag': 'WE_WD'}},
#  {'制定相关运营策略和指标': {'end_index': 226, 'start_index': 216, 'tag': 'WE_WD'}},
#  {'带领团队实施计划': {'end_index': 235, 'start_index': 228, 'tag': 'WE_WD'}},
#  {'网站常态运营活动规划和推进执行': {'end_index': 253, 'start_index': 239, 'tag': 'WE_WD'}},
#  {'相关数据报告和统计': {'end_index': 264, 'start_index': 256, 'tag': 'WE_WD'}},
#  {'为公司决策层提供决策依据': {'end_index': 277, 'start_index': 266, 'tag': 'WE_WD'}},
#  {'轻量级产品和应用的策划': {'end_index': 290, 'start_index': 280, 'tag': 'WE_WD'}},
#  {'统筹产品': {'end_index': 295, 'start_index': 292, 'tag': 'WE_WD'}},
#  {'技术团队成员实施': {'end_index': 304, 'start_index': 297, 'tag': 'WE_WD'}}]
# [{'2021.8-2022.8': {'end_index': 387, 'start_index': 375, 'tag': 'WE_TM'}}]
# [{'广州灵心沙文化活动有限公司': {'end_index': 400, 'start_index': 388, 'tag': 'WE_OG'}}]
# [{'市场推广专员': {'end_index': 406, 'start_index': 401, 'tag': 'WE_RL'}}]
# [{'微博': {'end_index': 339, 'start_index': 338, 'tag': 'WE_WD'}},
#  {'微博': {'end_index': 344, 'start_index': 343, 'tag': 'WE_WD'}},
#  {'网络推广渠道搭建维护': {'end_index': 418, 'start_index': 409, 'tag': 'WE_WD'}},
#  {'包括QQ空间': {'end_index': 425, 'start_index': 420, 'tag': 'WE_WD'}},
#  {'微博': {'end_index': 428, 'start_index': 427, 'tag': 'WE_WD'}},
#  {'豆瓣等': {'end_index': 432, 'start_index': 430, 'tag': 'WE_WD'}},
#  {'负责软硬广投放': {'end_index': 442, 'start_index': 436, 'tag': 'WE_WD'}},
#  {'网络舆情监控': {'end_index': 449, 'start_index': 444, 'tag': 'WE_WD'}},
#  {'公关稿撰写': {'end_index': 455, 'start_index': 451, 'tag': 'WE_WD'}},
#  {'事件营销策划': {'end_index': 462, 'start_index': 457, 'tag': 'WE_WD'}},
#  {'标书制作和撰写': {'end_index': 472, 'start_index': 466, 'tag': 'WE_WD'}},
#  {'甲方沟通工作': {'end_index': 479, 'start_index': 474, 'tag': 'WE_WD'}}]
# [{'2018.9-2021.6': {'end_index': 75, 'start_index': 63, 'tag': 'ED_TM'}}]
# [{'华南师范大学附属中学': {'end_index': 85, 'start_index': 76, 'tag': 'ED_SC'}}]
# [{'高中': {'end_index': 87, 'start_index': 86, 'tag': 'ED_DG'}}]
# [{'主修课程': {'end_index': 91, 'start_index': 88, 'tag': 'ED_ES'}},
#  {'基本会计': {'end_index': 95, 'start_index': 92, 'tag': 'ED_ES'}},
#  {'统计学': {'end_index': 99, 'start_index': 97, 'tag': 'ED_ES'}},
#  {'市场营销': {'end_index': 104, 'start_index': 101, 'tag': 'ED_ES'}},
#  {'国际市场营销': {'end_index': 111, 'start_index': 106, 'tag': 'ED_ES'}},
#  {'市场营销': {'end_index': 111, 'start_index': 108, 'tag': 'ED_ES'}},
#  {'市场调查与预测': {'end_index': 119, 'start_index': 113, 'tag': 'ED_ES'}},
#  {'商业心理学': {'end_index': 125, 'start_index': 121, 'tag': 'ED_ES'}},
#  {'广告学': {'end_index': 129, 'start_index': 127, 'tag': 'ED_ES'}},
#  {'公共关系学': {'end_index': 135, 'start_index': 131, 'tag': 'ED_ES'}},
#  {'货币银行学': {'end_index': 141, 'start_index': 137, 'tag': 'ED_ES'}},
#  {'经济法': {'end_index': 145, 'start_index': 143, 'tag': 'ED_ES'}},
#  {'国际贸易': {'end_index': 150, 'start_index': 147, 'tag': 'ED_ES'}},
#  {'大学英语': {'end_index': 155, 'start_index': 152, 'tag': 'ED_ES'}},
#  {'计算机应用等': {'end_index': 166, 'start_index': 161, 'tag': 'ED_ES'}},
#  {'市场营销': {'end_index': 553, 'start_index': 550, 'tag': 'ED_ES'}}]
# [{'蔡于纬': {'end_index': 2, 'start_index': 0, 'tag': 'NM'}},
#  {'23': {'end_index': 16, 'start_index': 15, 'tag': 'AG'}},
#  {'13511223344': {'end_index': 40, 'start_index': 30, 'tag': 'TL'}},
#  {'广东省广州市': {'end_index': 26, 'start_index': 21, 'tag': 'LV'}},
#  {'2022.08至今': {'end_index': 180, 'start_index': 172, 'tag': 'WE_TM'}},
#  {'卓望信息科技有限公司': {'end_index': 190, 'start_index': 181, 'tag': 'WE_OG'}},
#  {'营运推广主管': {'end_index': 196, 'start_index': 191, 'tag': 'WE_RL'}},
#  {'负责社会化媒体营销团队的搭建工作': {'end_index': 214, 'start_index': 199, 'tag': 'WE_WD'}},
#  {'制定相关运营策略和指标': {'end_index': 226, 'start_index': 216, 'tag': 'WE_WD'}},
#  {'带领团队实施计划': {'end_index': 235, 'start_index': 228, 'tag': 'WE_WD'}},
#  {'网站常态运营活动规划和推进执行': {'end_index': 253, 'start_index': 239, 'tag': 'WE_WD'}},
#  {'相关数据报告和统计': {'end_index': 264, 'start_index': 256, 'tag': 'WE_WD'}},
#  {'为公司决策层提供决策依据': {'end_index': 277, 'start_index': 266, 'tag': 'WE_WD'}},
#  {'轻量级产品和应用的策划': {'end_index': 290, 'start_index': 280, 'tag': 'WE_WD'}},
#  {'统筹产品': {'end_index': 295, 'start_index': 292, 'tag': 'WE_WD'}},
#  {'技术团队成员实施': {'end_index': 304, 'start_index': 297, 'tag': 'WE_WD'}},
#  {'2021.8-2022.8': {'end_index': 387, 'start_index': 375, 'tag': 'WE_TM'}},
#  {'广州灵心沙文化活动有限公司': {'end_index': 400, 'start_index': 388, 'tag': 'WE_OG'}},
#  {'市场推广专员': {'end_index': 406, 'start_index': 401, 'tag': 'WE_RL'}},
#  {'微博': {'end_index': 339, 'start_index': 338, 'tag': 'WE_WD'}},
#  {'微博': {'end_index': 344, 'start_index': 343, 'tag': 'WE_WD'}},
#  {'网络推广渠道搭建维护': {'end_index': 418, 'start_index': 409, 'tag': 'WE_WD'}},
#  {'包括QQ空间': {'end_index': 425, 'start_index': 420, 'tag': 'WE_WD'}},
#  {'微博': {'end_index': 428, 'start_index': 427, 'tag': 'WE_WD'}},
#  {'豆瓣等': {'end_index': 432, 'start_index': 430, 'tag': 'WE_WD'}},
#  {'负责软硬广投放': {'end_index': 442, 'start_index': 436, 'tag': 'WE_WD'}},
#  {'网络舆情监控': {'end_index': 449, 'start_index': 444, 'tag': 'WE_WD'}},
#  {'公关稿撰写': {'end_index': 455, 'start_index': 451, 'tag': 'WE_WD'}},
#  {'事件营销策划': {'end_index': 462, 'start_index': 457, 'tag': 'WE_WD'}},
#  {'标书制作和撰写': {'end_index': 472, 'start_index': 466, 'tag': 'WE_WD'}},
#  {'甲方沟通工作': {'end_index': 479, 'start_index': 474, 'tag': 'WE_WD'}},
#  {'2018.9-2021.6': {'end_index': 75, 'start_index': 63, 'tag': 'ED_TM'}},
#  {'华南师范大学附属中学': {'end_index': 85, 'start_index': 76, 'tag': 'ED_SC'}},
#  {'高中': {'end_index': 87, 'start_index': 86, 'tag': 'ED_DG'}},
#  {'主修课程': {'end_index': 91, 'start_index': 88, 'tag': 'ED_ES'}},
#  {'基本会计': {'end_index': 95, 'start_index': 92, 'tag': 'ED_ES'}},
#  {'统计学': {'end_index': 99, 'start_index': 97, 'tag': 'ED_ES'}},
#  {'市场营销': {'end_index': 104, 'start_index': 101, 'tag': 'ED_ES'}},
#  {'国际市场营销': {'end_index': 111, 'start_index': 106, 'tag': 'ED_ES'}},
#  {'市场营销': {'end_index': 111, 'start_index': 108, 'tag': 'ED_ES'}},
#  {'市场调查与预测': {'end_index': 119, 'start_index': 113, 'tag': 'ED_ES'}},
#  {'商业心理学': {'end_index': 125, 'start_index': 121, 'tag': 'ED_ES'}},
#  {'广告学': {'end_index': 129, 'start_index': 127, 'tag': 'ED_ES'}},
#  {'公共关系学': {'end_index': 135, 'start_index': 131, 'tag': 'ED_ES'}},
#  {'货币银行学': {'end_index': 141, 'start_index': 137, 'tag': 'ED_ES'}},
#  {'经济法': {'end_index': 145, 'start_index': 143, 'tag': 'ED_ES'}},
#  {'国际贸易': {'end_index': 150, 'start_index': 147, 'tag': 'ED_ES'}},
#  {'大学英语': {'end_index': 155, 'start_index': 152, 'tag': 'ED_ES'}},
#  {'计算机应用等': {'end_index': 166, 'start_index': 161, 'tag': 'ED_ES'}},
#  {'市场营销': {'end_index': 553, 'start_index': 550, 'tag': 'ED_ES'}},
#  {'本人有丰富的营销知识体系做基础': {'end_index': 546, 'start_index': 532, 'tag': 'SA'}},
#  {'对于市场营销方面的前沿和动向有一定的了解': {'end_index': 567, 'start_index': 548, 'tag': 'SA'}},
#  {'善于分析和吸取经验': {'end_index': 577, 'start_index': 569, 'tag': 'SA'}},
#  {'熟悉网络推广': {'end_index': 584, 'start_index': 579, 'tag': 'SA'}},
#  {'尤其是社会化媒体方面': {'end_index': 595, 'start_index': 586, 'tag': 'SA'}},
#  {'有独到的见解和经验': {'end_index': 605, 'start_index': 597, 'tag': 'SA'}},
#  {'个性开朗': {'end_index': 610, 'start_index': 607, 'tag': 'SA'}},
#  {'容易相处': {'end_index': 615, 'start_index': 612, 'tag': 'SA'}},
#  {'团队荣誉感强': {'end_index': 622, 'start_index': 617, 'tag': 'SA'}},
#  {'市场专员': {'end_index': 11, 'start_index': 8, 'tag': 'CO'}},
#  {'CET-6': {'end_index': 493, 'start_index': 489, 'tag': 'SK'}},
#  {'优秀的听说写能力': {'end_index': 502, 'start_index': 495, 'tag': 'SK'}},
#  {'计算机二级': {'end_index': 507, 'start_index': 503, 'tag': 'SK'}},
#  {'熟悉计算机各项操作': {'end_index': 517, 'start_index': 509, 'tag': 'SK'}},
#  {'高级营销员': {'end_index': 522, 'start_index': 518, 'tag': 'SK'}},
#  {'国家职业资格四级': {'end_index': 531, 'start_index': 524, 'tag': 'SK'}},
#  {'service@500d.me': {'end_index': 58, 'start_index': 44, 'tag': 'EM'}}]

# %%
# 编码-
# 初始化标注列表
tagged_text = ['O'] * len(text)

# 更新标注信息
for annotation in all_tag_index:
    for value, info in annotation.items():
        start, end, tag = info['start_index'], info['end_index'], info['tag']
        tagged_text[start] = 'B-' + tag  # 标记开始
        for i in range(start + 1, end+1 ):
            tagged_text[i] = 'I-' + tag  # 标记内部
# 生成最终的标注结果
final_annotations = [[text[i], tagged_text[i]] for i in range(len(text))]

# 打印结果
for item in final_annotations:
    print(f"{item[0]} {item[1]}")

# tag 代表没有标注第几次经历下标和标注类别名字
# tag_with_name 代表标注类别名字被标注
# tag_with_idx 代表标注第几次经历下标
# tag_wtih_idx_name 代表没有标注第几次经历下标和标注类别名字

with open ('./Corpus_Path/2024年03月03日15时01分/101/tag_with_idx.txt', 'w', encoding='utf-8') as f:
    for item in final_annotations:
        f.write(f"{item[0]} {item[1]}\n")
# Out:
# 蔡 B-NM
# 于 I-NM
# 纬 I-NM
# 求 O
# 职 O
# 意 O
# 向 O
# ： O
# 市 B-CO
# 场 I-CO
# 专 I-CO
# 员 I-CO
# 年 O
# 龄 O
# ： O
# 2 B-AG
# 3 I-AG
# 岁 O
# 地 O
# 址 O
# ： O
# 广 B-LV
# 东 I-LV
# 省 I-LV
# 广 I-LV
# 州 I-LV
# 市 I-LV
# 电 O
# 话 O
# ： O
# 1 B-TL
# 3 I-TL
# 5 I-TL
# 1 I-TL
# 1 I-TL
# 2 I-TL
# 2 I-TL
# 3 I-TL
# 3 I-TL
# 4 I-TL
# 4 I-TL
# 邮 O
# 箱 O
# ： O
# s B-EM
# e I-EM
# r I-EM
# v I-EM
# i I-EM
# c I-EM
# e I-EM
# @ I-EM
# 5 I-EM
# 0 I-EM
# 0 I-EM
# d I-EM
# . I-EM
# m I-EM
# e I-EM
# 教 O
# 育 O
# 背 O
# 景 O
# 2 B-ED_TM
# 0 I-ED_TM
# 1 I-ED_TM
# 8 I-ED_TM
# . I-ED_TM
# 9 I-ED_TM
# - I-ED_TM
# 2 I-ED_TM
# 0 I-ED_TM
# 2 I-ED_TM
# 1 I-ED_TM
# . I-ED_TM
# 6 I-ED_TM
# 华 B-ED_SC
# 南 I-ED_SC
# 师 I-ED_SC
# 范 I-ED_SC
# 大 I-ED_SC
# 学 I-ED_SC
# 附 I-ED_SC
# 属 I-ED_SC
# 中 I-ED_SC
# 学 I-ED_SC
# 高 B-ED_DG
# 中 I-ED_DG
# 主 B-ED_ES
# 修 I-ED_ES
# 课 I-ED_ES
# 程 I-ED_ES
# 基 B-ED_ES
# 本 I-ED_ES
# 会 I-ED_ES
# 计 I-ED_ES
# 、 O
# 统 B-ED_ES
# 计 I-ED_ES
# 学 I-ED_ES
# 、 O
# 市 B-ED_ES
# 场 I-ED_ES
# 营 I-ED_ES
# 销 I-ED_ES
# 、 O
# 国 B-ED_ES
# 际 I-ED_ES
# 市 B-ED_ES
# 场 I-ED_ES
# 营 I-ED_ES
# 销 I-ED_ES
# 、 O
# 市 B-ED_ES
# 场 I-ED_ES
# 调 I-ED_ES
# 查 I-ED_ES
# 与 I-ED_ES
# 预 I-ED_ES
# 测 I-ED_ES
# 、 O
# 商 B-ED_ES
# 业 I-ED_ES
# 心 I-ED_ES
# 理 I-ED_ES
# 学 I-ED_ES
# 、 O
# 广 B-ED_ES
# 告 I-ED_ES
# 学 I-ED_ES
# 、 O
# 公 B-ED_ES
# 共 I-ED_ES
# 关 I-ED_ES
# 系 I-ED_ES
# 学 I-ED_ES
# 、 O
# 货 B-ED_ES
# 币 I-ED_ES
# 银 I-ED_ES
# 行 I-ED_ES
# 学 I-ED_ES
# 、 O
# 经 B-ED_ES
# 济 I-ED_ES
# 法 I-ED_ES
# 、 O
# 国 B-ED_ES
# 际 I-ED_ES
# 贸 I-ED_ES
# 易 I-ED_ES
# 、 O
# 大 B-ED_ES
# 学 I-ED_ES
# 英 I-ED_ES
# 语 I-ED_ES
# 、 O
# 济 O
# 数 O
# 学 O
# 、 O
# 计 B-ED_ES
# 算 I-ED_ES
# 机 I-ED_ES
# 应 I-ED_ES
# 用 I-ED_ES
# 等 I-ED_ES
# 。 O
# 工 O
# 作 O
# 背 O
# 景 O
# 2 B-WE_TM
# 0 I-WE_TM
# 2 I-WE_TM
# 2 I-WE_TM
# . I-WE_TM
# 0 I-WE_TM
# 8 I-WE_TM
# 至 I-WE_TM
# 今 I-WE_TM
# 卓 B-WE_OG
# 望 I-WE_OG
# 信 I-WE_OG
# 息 I-WE_OG
# 科 I-WE_OG
# 技 I-WE_OG
# 有 I-WE_OG
# 限 I-WE_OG
# 公 I-WE_OG
# 司 I-WE_OG
# 营 B-WE_RL
# 运 I-WE_RL
# 推 I-WE_RL
# 广 I-WE_RL
# 主 I-WE_RL
# 管 I-WE_RL
# 1 O
# 、 O
# 负 B-WE_WD
# 责 I-WE_WD
# 社 I-WE_WD
# 会 I-WE_WD
# 化 I-WE_WD
# 媒 I-WE_WD
# 体 I-WE_WD
# 营 I-WE_WD
# 销 I-WE_WD
# 团 I-WE_WD
# 队 I-WE_WD
# 的 I-WE_WD
# 搭 I-WE_WD
# 建 I-WE_WD
# 工 I-WE_WD
# 作 I-WE_WD
# ， O
# 制 B-WE_WD
# 定 I-WE_WD
# 相 I-WE_WD
# 关 I-WE_WD
# 运 I-WE_WD
# 营 I-WE_WD
# 策 I-WE_WD
# 略 I-WE_WD
# 和 I-WE_WD
# 指 I-WE_WD
# 标 I-WE_WD
# ， O
# 带 B-WE_WD
# 领 I-WE_WD
# 团 I-WE_WD
# 队 I-WE_WD
# 实 I-WE_WD
# 施 I-WE_WD
# 计 I-WE_WD
# 划 I-WE_WD
# ； O
# 2 O
# 、 O
# 网 B-WE_WD
# 站 I-WE_WD
# 常 I-WE_WD
# 态 I-WE_WD
# 运 I-WE_WD
# 营 I-WE_WD
# 活 I-WE_WD
# 动 I-WE_WD
# 规 I-WE_WD
# 划 I-WE_WD
# 和 I-WE_WD
# 推 I-WE_WD
# 进 I-WE_WD
# 执 I-WE_WD
# 行 I-WE_WD
# 3 O
# 、 O
# 相 B-WE_WD
# 关 I-WE_WD
# 数 I-WE_WD
# 据 I-WE_WD
# 报 I-WE_WD
# 告 I-WE_WD
# 和 I-WE_WD
# 统 I-WE_WD
# 计 I-WE_WD
# ， O
# 为 B-WE_WD
# 公 I-WE_WD
# 司 I-WE_WD
# 决 I-WE_WD
# 策 I-WE_WD
# 层 I-WE_WD
# 提 I-WE_WD
# 供 I-WE_WD
# 决 I-WE_WD
# 策 I-WE_WD
# 依 I-WE_WD
# 据 I-WE_WD
# 4 O
# 、 O
# 轻 B-WE_WD
# 量 I-WE_WD
# 级 I-WE_WD
# 产 I-WE_WD
# 品 I-WE_WD
# 和 I-WE_WD
# 应 I-WE_WD
# 用 I-WE_WD
# 的 I-WE_WD
# 策 I-WE_WD
# 划 I-WE_WD
# ， O
# 统 B-WE_WD
# 筹 I-WE_WD
# 产 I-WE_WD
# 品 I-WE_WD
# 、 O
# 技 B-WE_WD
# 术 I-WE_WD
# 团 I-WE_WD
# 队 I-WE_WD
# 成 I-WE_WD
# 员 I-WE_WD
# 实 I-WE_WD
# 施 I-WE_WD
# 。 O
# 工 O
# 作 O
# 成 O
# 果 O
# 社 O
# 会 O
# 化 O
# 媒 O
# 体 O
# 账 O
# 号 O
# 总 O
# 共 O
# 涨 O
# 粉 O
# 6 O
# 7 O
# 万 O
# （ O
# 包 O
# 含 O
# Q O
# Q O
# 空 O
# 间 O
# ， O
# 人 O
# 人 O
# 网 O
# ， O
# 新 O
# 浪 O
# 微 B-WE_WD
# 博 I-WE_WD
# ， O
# 腾 O
# 讯 O
# 微 B-WE_WD
# 博 I-WE_WD
# ） O
# 日 O
# 均 O
# 互 O
# 动 O
# 量 O
# 相 O
# 比 O
# 接 O
# 手 O
# 前 O
# 提 O
# 升 O
# 1 O
# 0 O
# 0 O
# 0 O
# % O
# ， O
# 评 O
# 论 O
# 转 O
# 发 O
# 量 O
# 级 O
# 达 O
# 到 O
# 百 O
# 千 O
# 级 O
# 2 B-WE_TM
# 0 I-WE_TM
# 2 I-WE_TM
# 1 I-WE_TM
# . I-WE_TM
# 8 I-WE_TM
# - I-WE_TM
# 2 I-WE_TM
# 0 I-WE_TM
# 2 I-WE_TM
# 2 I-WE_TM
# . I-WE_TM
# 8 I-WE_TM
# 广 B-WE_OG
# 州 I-WE_OG
# 灵 I-WE_OG
# 心 I-WE_OG
# 沙 I-WE_OG
# 文 I-WE_OG
# 化 I-WE_OG
# 活 I-WE_OG
# 动 I-WE_OG
# 有 I-WE_OG
# 限 I-WE_OG
# 公 I-WE_OG
# 司 I-WE_OG
# 市 B-WE_RL
# 场 I-WE_RL
# 推 I-WE_RL
# 广 I-WE_RL
# 专 I-WE_RL
# 员 I-WE_RL
# 1 O
# 、 O
# 网 B-WE_WD
# 络 I-WE_WD
# 推 I-WE_WD
# 广 I-WE_WD
# 渠 I-WE_WD
# 道 I-WE_WD
# 搭 I-WE_WD
# 建 I-WE_WD
# 维 I-WE_WD
# 护 I-WE_WD
# ， O
# 包 B-WE_WD
# 括 I-WE_WD
# Q I-WE_WD
# Q I-WE_WD
# 空 I-WE_WD
# 间 I-WE_WD
# 、 O
# 微 B-WE_WD
# 博 I-WE_WD
# 、 O
# 豆 B-WE_WD
# 瓣 I-WE_WD
# 等 I-WE_WD
# ； O
# 2 O
# 、 O
# 负 B-WE_WD
# 责 I-WE_WD
# 软 I-WE_WD
# 硬 I-WE_WD
# 广 I-WE_WD
# 投 I-WE_WD
# 放 I-WE_WD
# ， O
# 网 B-WE_WD
# 络 I-WE_WD
# 舆 I-WE_WD
# 情 I-WE_WD
# 监 I-WE_WD
# 控 I-WE_WD
# ， O
# 公 B-WE_WD
# 关 I-WE_WD
# 稿 I-WE_WD
# 撰 I-WE_WD
# 写 I-WE_WD
# ， O
# 事 B-WE_WD
# 件 I-WE_WD
# 营 I-WE_WD
# 销 I-WE_WD
# 策 I-WE_WD
# 划 I-WE_WD
# ； O
# 3 O
# 、 O
# 标 B-WE_WD
# 书 I-WE_WD
# 制 I-WE_WD
# 作 I-WE_WD
# 和 I-WE_WD
# 撰 I-WE_WD
# 写 I-WE_WD
# ， O
# 甲 B-WE_WD
# 方 I-WE_WD
# 沟 I-WE_WD
# 通 I-WE_WD
# 工 I-WE_WD
# 作 I-WE_WD
# 。 O
# 技 O
# 能 O
# 证 O
# 书 O
# 自 O
# 我 O
# 评 O
# 价 O
# C B-SK
# E I-SK
# T I-SK
# - I-SK
# 6 I-SK
# ， O
# 优 B-SK
# 秀 I-SK
# 的 I-SK
# 听 I-SK
# 说 I-SK
# 写 I-SK
# 能 I-SK
# 力 I-SK
# 计 B-SK
# 算 I-SK
# 机 I-SK
# 二 I-SK
# 级 I-SK
# ， O
# 熟 B-SK
# 悉 I-SK
# 计 I-SK
# 算 I-SK
# 机 I-SK
# 各 I-SK
# 项 I-SK
# 操 I-SK
# 作 I-SK
# 高 B-SK
# 级 I-SK
# 营 I-SK
# 销 I-SK
# 员 I-SK
# ， O
# 国 B-SK
# 家 I-SK
# 职 I-SK
# 业 I-SK
# 资 I-SK
# 格 I-SK
# 四 I-SK
# 级 I-SK
# 本 B-SA
# 人 I-SA
# 有 I-SA
# 丰 I-SA
# 富 I-SA
# 的 I-SA
# 营 I-SA
# 销 I-SA
# 知 I-SA
# 识 I-SA
# 体 I-SA
# 系 I-SA
# 做 I-SA
# 基 I-SA
# 础 I-SA
# ； O
# 对 B-SA
# 于 I-SA
# 市 I-SA
# 场 I-SA
# 营 I-SA
# 销 I-SA
# 方 I-SA
# 面 I-SA
# 的 I-SA
# 前 I-SA
# 沿 I-SA
# 和 I-SA
# 动 I-SA
# 向 I-SA
# 有 I-SA
# 一 I-SA
# 定 I-SA
# 的 I-SA
# 了 I-SA
# 解 I-SA
# ， O
# 善 B-SA
# 于 I-SA
# 分 I-SA
# 析 I-SA
# 和 I-SA
# 吸 I-SA
# 取 I-SA
# 经 I-SA
# 验 I-SA
# ； O
# 熟 B-SA
# 悉 I-SA
# 网 I-SA
# 络 I-SA
# 推 I-SA
# 广 I-SA
# ， O
# 尤 B-SA
# 其 I-SA
# 是 I-SA
# 社 I-SA
# 会 I-SA
# 化 I-SA
# 媒 I-SA
# 体 I-SA
# 方 I-SA
# 面 I-SA
# ， O
# 有 B-SA
# 独 I-SA
# 到 I-SA
# 的 I-SA
# 见 I-SA
# 解 I-SA
# 和 I-SA
# 经 I-SA
# 验 I-SA
# ； O
# 个 B-SA
# 性 I-SA
# 开 I-SA
# 朗 I-SA
# ， O
# 容 B-SA
# 易 I-SA
# 相 I-SA
# 处 I-SA
# ， O
# 团 B-SA
# 队 I-SA
# 荣 I-SA
# 誉 I-SA
# 感 I-SA
# 强 I-SA
# ； O
